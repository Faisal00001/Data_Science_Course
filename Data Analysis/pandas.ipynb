# %%
print('Hi')
# Out:
# Hi

# %%
import pandas as pd

# %%
#Series 
data = [1,2,3,4,5]
series = pd.Series(data)
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data ={
    'a':1,
    'b':2,
    'c':3
}
series_dict = pd.Series(data)
series_dict
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data =[10,20,30]
index =['a','b','c']
pd.Series(data,index= index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#Dataframe 2D
data ={
    'Name':['Faisal','Osman'],
    'Age':[20,30],
    'City':['Dhaka','Jeshore']
}
df = pd.DataFrame(data)
df
# Out:
#      Name  Age     City
# 0  Faisal   20    Dhaka
# 1   Osman   30  Jeshore

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
np.array(df)
# Out:
# array([['Faisal', 20, 'Dhaka'],
#        ['Osman', 30, 'Jeshore']], dtype=object)

# %%
data = [
      {
          'Name':'Faisal',
          'Age':32,
          'City':'Jashore'
      },
      {
          'Name':'Osman',
          'Age':32,
          'City':'Dhaka'
      },
      {
          'Name':'Rakib',
          'Age':32,
          'City':'Dhaka'
      }
]

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age     City
# 0  Faisal   32  Jashore
# 1   Osman   32    Dhaka
# 2   Rakib   32    Dhaka

# %%
df=pd.read_csv('sales_data.csv')

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df.tail(5)
# Out:
#      Transaction ID        Date Product Category  \
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# ...

# %%
# Accessing data fromm data frame
data
# Out:
# [{'Name': 'Faisal', 'Age': 32, 'City': 'Jashore'},
#  {'Name': 'Osman', 'Age': 32, 'City': 'Dhaka'},
#  {'Name': 'Rakib', 'Age': 32, 'City': 'Dhaka'}]

# %%
data ={
    'Name':['Faisal','Osman'],
    'Age':[20,30],
    'City':['Dhaka','Jeshore']
}

# %%
data
# Out:
# {'Name': ['Faisal', 'Osman'], 'Age': [20, 30], 'City': ['Dhaka', 'Jeshore']}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Name  Age     City
# 0  Faisal   20    Dhaka
# 1   Osman   30  Jeshore

# %%
df['Name']
# Out:
# 0    Faisal
# 1     Osman
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.loc[0]
# Out:
# Name    Faisal
# Age         20
# City     Dhaka
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name    Faisal
# Age         20
# City     Dhaka
# Name: 0, dtype: object

# %%
df.loc[0][0]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_4024\2527876973.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0]
# 'Faisal'

# %%
df.loc[0][2]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_4024\2880214942.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][2]
# 'Dhaka'

# %%
#specing a specific item
df['Name']
# Out:
# 0    Faisal
# 1     Osman
# Name: Name, dtype: object

# %%
df
# Out:
#      Name  Age     City
# 0  Faisal   20    Dhaka
# 1   Osman   30  Jeshore

# %%
df.at[1,'Age']
# Out:
# np.int64(30)

# %%
df.at[1,'Name']
# Out:
# 'Osman'

# %%
df.iat[1,2]
# Out:
# 'Jeshore'

# %%
df
# Out:
#      Name  Age     City
# 0  Faisal   20    Dhaka
# 1   Osman   30  Jeshore

# %%
### Data manupulation with data frame
#Adding new column
df['Salary'] = [5000,6000]

# %%
df
# Out:
#      Name  Age     City  Salary
# 0  Faisal   20    Dhaka    5000
# 1   Osman   30  Jeshore    6000

# %%
#Remove a column
#drop first check on row index , so make it column
df.drop('Salary',axis=1)
# Out:
#      Name  Age     City
# 0  Faisal   20    Dhaka
# 1   Osman   30  Jeshore

# %%
#again present salary so inorder to permanately remove use inplace operation
df
# Out:
#      Name  Age     City  Salary
# 0  Faisal   20    Dhaka    5000
# 1   Osman   30  Jeshore    6000

# %%
df.drop('Salary',axis=1,inplace=True)

# %%
df
# Out:
#      Name  Age     City
# 0  Faisal   20    Dhaka
# 1   Osman   30  Jeshore

# %%
## Add age to column
df['Age']=df['Age']+1

# %%
df
# Out:
#      Name  Age     City
# 0  Faisal   21    Dhaka
# 1   Osman   31  Jeshore

# %%
df.drop(1)
# Out:
#      Name  Age   City
# 0  Faisal   21  Dhaka

# %%
df
# Out:
#      Name  Age     City
# 0  Faisal   21    Dhaka
# 1   Osman   31  Jeshore

# %%
df.drop(1,inplace=True)

# %%
df
# Out:
#      Name  Age   City
# 0  Faisal   21  Dhaka

# %%
df.head(5)
# Out:
#      Name  Age   City
# 0  Faisal   21  Dhaka

# %%
df = pd.read_csv('sales_data.csv')
df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
print('Data types',df.dtypes)
# Out:
# Data types Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object

# %%
print('Satisticl Summery',df.describe())
# Out:
# Satisticl Summery        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
grouped = df.groupby('Category')['Value'].mean()
print("Mean value by category ",grouped)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 grouped = df.groupby('Category')['Value'].mean()
#       2 print("Mean value by category ",grouped)
#
# File d:\Data Science Krish Nayek\Code2\python\venv\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...

# %%
df = pd.read_csv('data.csv')
df.head(5)
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.tail(10)
# Out:
#           Date Category  Value   Product  Sales Region
# 40  2023-02-10        B   15.0  Product1  578.0   East
# 41  2023-02-11        C   97.0  Product1  256.0   East
# 42  2023-02-12        A   93.0  Product3  164.0   West
# 43  2023-02-13        A   43.0  Product3  949.0   East
# 44  2023-02-14        A   96.0  Product3  830.0   East
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
df.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
#Handling missing values
df.isnull()
# Out:
#      Date  Category  Value  Product  Sales  Region
# 0   False     False  False    False  False   False
# 1   False     False  False    False  False   False
# 2   False     False  False    False  False   False
# 3   False     False  False    False  False   False
# 4   False     False  False    False  False   False
# 5   False     False  False    False  False   False
# 6   False     False  False    False  False   False
# 7   False     False  False    False  False   False
# 8   False     False  False    False  False   False
# 9   False     False  False    False  False   False
# 10  False     False  False    False  False   False
# 11  False     False  False    False   True   False
# 12  False     False  False    False  False   False
# 13  False     False  False    False  False   False
# 14  False     False  False    False  False   False
# 15  False     False   True    False  False   False
# 16  False     False  False    False  False   False
# ...

# %%
df.isnull().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35     True
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
df.isnull().any()
# Out:
# Date        False
# Category    False
# Value        True
# Product     False
# Sales        True
# Region      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
#Fill missing value
df_filled = df.fillna(0)
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    0.0   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    0.0  Product1  895.0  North
# ...

# %%
#Filling mmissing value with the mean of the column
df['Sales_fillNA'] = df['Sales'].fillna(df['Sales'].mean())
df
# Out:
#           Date Category  Value   Product  Sales Region  Sales_fillNA
# 0   2023-01-01        A   28.0  Product1  754.0   East    754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North    110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East    398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East    522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North    869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West    192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East    936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West    488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West    772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West    834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North    842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West    557.130435
# 12  2023-01-13        A   70.0  Product3  628.0  South    628.000000
# ...

# %%
df.dtypes
# Out:
# Date             object
# Category         object
# Value           float64
# Product          object
# Sales           float64
# Region           object
# Sales_fillNA    float64
# dtype: object

# %%
#Renaming the columns
df=df.rename(columns={'Date':'Sales Date'})
df
# Out:
#     Sales Date Category  Value   Product  Sales Region  Sales_fillNA
# 0   2023-01-01        A   28.0  Product1  754.0   East    754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North    110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East    398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East    522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North    869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West    192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East    936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West    488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West    772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West    834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North    842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West    557.130435
# 12  2023-01-13        A   70.0  Product3  628.0  South    628.000000
# ...

# %%
#Change data types
df['Value_new'] = df['Value'].fillna(df['Value'].mean()).astype(int)
df.head(10)
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_fillNA  Value_new
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0         28
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0         39
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0         32
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0          8
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0         26
# 5  2023-01-06        B   54.0  Product3  192.0   West         192.0         54
# 6  2023-01-07        A   16.0  Product1  936.0   East         936.0         16
# 7  2023-01-08        C   89.0  Product1  488.0   West         488.0         89
# 8  2023-01-09        C   37.0  Product3  772.0   West         772.0         37
# 9  2023-01-10        A   22.0  Product2  834.0   West         834.0         22

# %%
df['New Value'] = df['Value'].apply(lambda x:x*2)
df.head(10)
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_fillNA  \
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0
# 5  2023-01-06        B   54.0  Product3  192.0   West         192.0
# 6  2023-01-07        A   16.0  Product1  936.0   East         936.0
# 7  2023-01-08        C   89.0  Product1  488.0   West         488.0
# 8  2023-01-09        C   37.0  Product3  772.0   West         772.0
# 9  2023-01-10        A   22.0  Product2  834.0   West         834.0
#
#    Value_new  New Value
# 0         28       56.0
# 1         39       78.0
# 2         32       64.0
# 3          8       16.0
# 4         26       52.0
# 5         54      108.0
# 6         16       32.0
# ...

# %%
## Data Aggreting anf Grouping
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_fillNA  \
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0
#
#    Value_new  New Value
# 0         28       56.0
# 1         39       78.0
# 2         32       64.0
# 3          8       16.0
# 4         26       52.0

# %%
grouped_mean = df.groupby('Product')['Value'].mean()
grouped_mean
# Out:
# Product
# Product1    46.214286
# Product2    52.800000
# Product3    55.166667
# Name: Value, dtype: float64

# %%
grouped_sum=df.groupby(['Product','Region'])['Value'].sum()
print(grouped_sum)
# Out:
# Product   Region
# Product1  East      292.0
#           North       9.0
#           South     100.0
#           West      246.0
# Product2  East       56.0
#           North     127.0
#           South     181.0
#           West      428.0
# Product3  East      202.0
#           North     203.0
#           South     215.0
#           West      373.0
# Name: Value, dtype: float64

# %%
df.groupby(['Product','Region'])['Value'].mean()
# Out:
# Product   Region
# Product1  East      41.714286
#           North      4.500000
#           South     50.000000
#           West      82.000000
# Product2  East      28.000000
#           North     63.500000
#           South     60.333333
#           West      53.500000
# Product3  East      50.500000
#           North     40.600000
#           South     71.666667
#           West      62.166667
# Name: Value, dtype: float64

# %%
#aggregate multiple functions
grouped_agg =df.groupby('Region')['Value'].agg(['mean','sum','count'])
grouped_agg
# Out:
#              mean     sum  count
# Region
# East    42.307692   550.0     13
# North   37.666667   339.0      9
# South   62.000000   496.0      8
# West    61.588235  1047.0     17

# %%
#Merging and joining data frame
df1 = pd.DataFrame({'key':['A','B','C'],'Value1':[1,2,3]})
df2 = pd.DataFrame({'key':['A','B','D'],'Value2':[4,5,6]})

# %%
df1
# Out:
#   key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
##Merge the data frame on key coolumns
pd.merge(df1,df2,on="key",how="inner")
# Out:
#   key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1,df2,on="key",how="outer")
# Out:
#   key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1,df2,on="key",how="left")
# Out:
#   key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1,df2,on="key",how="right")
# Out:
#   key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6
